# %%
from rembg import remove
from PIL import Image

# %%
img_path = "images/img_flower.jfif"
inp = Image.open(img_path)

# %%
inp                                       # Original image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1000x1333>

# %%
out = remove(inp)
out                                         # Final output with removed background
# Out:
# <PIL.Image.Image image mode=RGBA size=1000x1333>
